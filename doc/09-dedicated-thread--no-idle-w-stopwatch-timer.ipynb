# %% [markdown]
# # Dedicated Thread
# ## 08 No Idle w/ Stopwatch Timer

# %%
import numpy as np
import pandas as pd

# %%
th_idle = pd.read_csv("./data/th-nosleep-sw-idle.csv", delimiter=';', decimal=',')
th_load = pd.read_csv("./data/th-nosleep-sw-load.csv", delimiter=';', decimal=',')
df_th = pd.concat([th_load, th_idle])
df_th.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   100% load  10000 non-null  float64
#  1   idle       10000 non-null  float64
# dtypes: float64(2)
# memory usage: 468.8 KB

# %%
df_th.describe()
# Out:
#           100% load          idle
# count  10000.000000  10000.000000
# mean       1.191838      1.000533
# std        1.771139      0.012566
# min        0.998400      0.991700
# 25%        1.000100      1.000100
# 50%        1.000100      1.000100
# 75%        1.000100      1.000100
# max       32.586600      1.558400

# %%
ax = df_th.plot(title="No Idle", logy=True)

ax.set(xlabel="Ticks", ylabel="milliseconds")
ax.legend(['100% load', 'Idle'], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
